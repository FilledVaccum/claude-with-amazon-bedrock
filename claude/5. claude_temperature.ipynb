# %% [markdown]
# # Temprature

# %% [markdown]
# ### Taking the code from notebook 4

# %%
## Keeping this cell same 
import boto3

#Setting up the client object instance
multiturn_client = boto3.client("bedrock-runtime", region_name = "us-west-2")

# Setting up the model ID -> Important to know the difference between model id and inference id
# model id can be available in a region but not in other, hence leverage inference profile
# Here to start with we are using model id
model_id = "us.anthropic.claude-sonnet-4-20250514-v1:0"


## Since I will append messages from conversations I will create a variable of type list to store the message
messages = []

# Both function combined are making context for the model

# function take 'text' as input and format it in required format and add it to message list - this is for user input
def add_user_message(messages, text):
    user_message = {
        "role" : "user",
        "content" : [
            { "text" : text }
        ]
    }
    messages.append(user_message)

# function take 'text' as input and format it in required format and add it to message list - this is for model output
def add_assistant_message(messages, text):
    user_message = {
        "role" : "assistant",
        "content" : [
            { "text" : text }
        ]
    }
    messages.append(user_message)

# %% [markdown]
# ### Most of the game now happen here in chat function playing with parameters

# %%
# Adding system Prompt - adding to request

# adding on more parameter - Temprature - default as 1.0
def chat(messages, system = None, temperature = 1.0):

    # Defining a variable  of dic type for parameters
    params = {
        "modelId": model_id, 
        "messages": messages,
        "inferenceConfig": {
            "temperature" : temperature
        }
    } # Defining a variable dic for parameters

    if system:  # if system prompt is passed to this function it will be add to params
        params["system"] = [{"text" : system}]

    response = multiturn_client.converse(**params) # pointers to param variable
    
    return response['output']['message']['content'][0]['text']

# %%
add_user_message(messages, "Write an interesting story")
assitant_response = chat(messages, system = None, temperature = 0.0)
add_assistant_message(messages, assitant_response)

# %%
# Running loop for continous input
print(assitant_response)
# Out:
# ## The Dream Architect
#
# Lena built dreams for a living, but she hadn't had one of her own in years.
#
# At Morpheus Industries, she crafted custom dreams for clients who could afford them. Flying dreams for the earthbound, adventure dreams for the bored, romance dreams for the lonely. She was the best architect in the business, weaving narratives so vivid that clients often preferred sleep to waking life.
#
# The irony wasn't lost on her—every night, she fell into dreamless black while others lived in the fantasies she'd designed.
#
# Her latest client was different. Marcus Chen, a 12-year-old boy, sat across from her desk with his parents, his eyes hollow with exhaustion.
#
# "He has nightmares," his mother explained. "Every night for six months. The doctors can't help."
#
# Lena studied the boy's file. Night terrors, sleep paralysis, recurring visions of a dark figure that followed him through twisted corridors. She'd seen similar cases—trauma dreams were the hardest to fix because they came from somewhere real.
#
# "What happened six months ago?" she asked gently.
#
# Marcus whispered, "My sister died in a car accident. I was supposed to be in the car too, but I stayed home sick."
#
# Lena's heart clenched. She understood survivor's guilt intimately—it's why she'd stopped dreaming in the first place, after her own brother's death years ago.
#
# That night, she did something she'd never done before. Instead of crafting a replacement dream, she entered Marcus's nightmare herself, using an experimental technique that could trap her mind in his subconscious.
#
# She found herself in a hospital corridor that stretched infinitely in both directions. At the far end, a shadow figure waited—not a monster, but a little girl.
#
# "You're not supposed to be here," the shadow-sister said to Marcus, who cowered behind Lena.
#
# "Neither are you," Lena replied softly. "You're supposed to be at peace."
#
# The shadow-girl looked confused. "But he needs me. He's guilty."
#
# "He's grieving," Lena corrected. "There's a difference."
#
# She knelt beside Marcus. "Your sister doesn't want you to suffer. She wants you to live—really live—for both of you."
#
# As she spoke, Lena felt something crack open in her own chest. The words she'd never said to herself, about her own brother, about her own guilt.
#
# The corridor began to brighten. The shadow-sister smiled and faded into warm light.
#
# Marcus woke up peacefully for the first time in months.
#
# But the real miracle happened to Lena. That night, she dreamed—not a crafted fantasy, but a simple, beautiful dream where she and her brother were children again, laughing in their grandmother's garden.
#
# She woke with tears on her cheeks and hope in her heart.
#
# Sometimes, the best way to heal others is to heal yourself first.

# %%
while True:
    # taking user input
    user_input = input(">")

    # taking user input -> formating in desired format -> appending it to messages
    add_user_message(messages, user_input)

    # formating the request and sending the request to model
    assitant_response = chat(messages)

    # printing the response from model - Extracted response
    print(assitant_response)

    # using model(assitant) output -> formating in desired format -> appending it to messages
    add_assistant_message(messages, assitant_response)
